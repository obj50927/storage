# %% [markdown]
# # Lab8:  Dimensionality reduction

# %% [markdown]
# For this Lab, you can only use the packages listed below.
#
# Useful documentation: https://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.eig.html#numpy.linalg.eig

# %%
# Run this cell
import numpy as np
import pandas as pd
from plotnine import *

# %% [markdown]
# ### Q1  (1+2+2+2+2+2+2 pts)

# %% [markdown]
# The cell below generates a 2x1000 matrix, each column consisting of a 2-d vector (whose components are independent gaussians).
#
# For you convience it is also stored as a dataframe (though by the conventions of 'tidy data' this has a 1000 rows and 2 columns, 'x' and 'y', hence we had to take the transpose of it with data.T). This might be helpful for plotting.

# %%
# Run this cell
np.random.seed(1)
data = np.random.normal(0,1,[2,1000])
data_df = pd.DataFrame(data.T, columns = ['x','y'])

# %% [markdown]
# a. Create a scatterplot of the dataset, with columns x and y on the x- and y- axes.

# %%
###
### YOUR CODE HERE
###
plot = ggplot()+geom_point(data_df,aes(x='x',y='y'))
print(plot)
# Out:
# <ggplot: (-9223363285037803772)>

# %% [markdown]
# b. Create a 1000-by-1000 Gram matrix. Recall this is a similarity matrix whose element (i,j) is the inner product of data points i and j. Lecture 14 gives a compact way to calculate this using matrix multiplication: the matrix multiplication of X transpose and X. Store the result in S and print it.
#
# (note: to multiply two matrices A and B, use the numpy method np.dot(A,B) or just A @ B)

# %%
###
### YOUR CODE HERE
###
S = np.dot(data.T,data)
print(S)
# Out:
# [[ 2.66197918 -0.62095543 -0.93577491 ...  0.0281372   0.47560651
#   -0.51619135]
#  [-0.62095543  6.29134357 -0.91256377 ...  2.28453675 -1.79122798
#   -3.25909413]
#  [-0.93577491 -0.91256377  0.53701349 ... -0.43141465  0.14195206
#    0.80323004]
#  ...
#  [ 0.0281372   2.28453675 -0.43141465 ...  0.85430299 -0.6212972
#   -1.26516371]
#  [ 0.47560651 -1.79122798  0.14195206 ... -0.6212972   0.54431882
#    0.83163853]
#  [-0.51619135 -3.25909413  0.80323004 ... -1.26516371  0.83163853
#    1.95823741]]

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# c. Calculate the eigenvalues and eigenvectors of S and store them in variables U and V respectively. Print out the top 10 eigenvalues (numpy automatically sorts them in decreasing absolute value).

# %%
###
### YOUR CODE HERE
###
U, V = np.linalg.eig(S)
print(U[0:10])
# Out:
# [ 1.06692290e+03+0.00000000e+00j  9.58676405e+02+0.00000000e+00j
#  -1.05469858e-14+7.17950277e-14j -1.05469858e-14-7.17950277e-14j
#  -6.60147921e-14+0.00000000e+00j  6.88646239e-14+0.00000000e+00j
#  -5.74858680e-14+2.22994986e-14j -5.74858680e-14-2.22994986e-14j
#  -4.15342137e-16+5.76354879e-14j -4.15342137e-16-5.76354879e-14j]

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# d. Because of numerical issues resulting from a 1000-by-1000 matrix, you will notice the eigenvalues are complex numbers (i.e. of the form a+bj). However, the imaginary components will be very small. Keep only the real component using the function np.real().
# Store the result in Ur and again print out the first 10 values.

# %%
###
### YOUR CODE HERE
###
Ur = np.real(U)
print(Ur[0:10])
# Out:
# [ 1.06692290e+03  9.58676405e+02 -1.05469858e-14 -1.05469858e-14
#  -6.60147921e-14  6.88646239e-14 -5.74858680e-14 -5.74858680e-14
#  -4.15342137e-16 -4.15342137e-16]

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# e. Assume the eigenvalues are numbered from 1 to 1000. Create a scatterplot whose x-value is the index of the eigenvalue, and y-value is the corresponding eigenvalue, i.e. each point is a pair (i, Ur[i])

# %%
###
### YOUR CODE HERE
###
df = pd.DataFrame(Ur,columns=["Ur"])
df = df.reset_index()
plt = ggplot() + geom_point(df,aes(x='index',y='Ur'))
print(plt)
# Out:
# <ggplot: (8751816929607)>

# %% [markdown]
# f. Now, suppose instead of measuring S exactly, we measure it noisily. Do this by adding independent normal random variables with mean 0 and standard deviation 5 to each element of S. The resulting matrix will no longer by symmetric, but that's ok: we will just focus on the real part of their eigenvalues.
#
# Repeat steps c,d and e to plot the eigenvalue spectrum of the noisy S.

# %%
###
### YOUR CODE HERE
###
norm = np.random.normal(0, 5, 1000)
S_n = S+norm

U_n, V_n = np.linalg.eig(S_n)
print(U_n[0:10])

Ur_n = np.real(U_n)
print(Ur_n[0:10])

df = pd.DataFrame(Ur_n,columns=["Ur_n"])
df = df.reset_index()
plt = ggplot() + geom_point(df,aes(x='index',y='Ur_n'))
print(plt)
# Out:
# [ 1.06084755e+03+0.00000000e+00j  9.52157151e+02+0.00000000e+00j
#  -9.82482539e+01+0.00000000e+00j  1.06381416e-13+2.76319095e-13j
#   1.06381416e-13-2.76319095e-13j  1.71923688e-13+1.08448214e-13j
#   1.71923688e-13-1.08448214e-13j -1.70336681e-13+7.34404328e-15j
#  -1.70336681e-13-7.34404328e-15j -1.17774958e-13+1.18851671e-13j]
# [ 1.06084755e+03  9.52157151e+02 -9.82482539e+01  1.06381416e-13
#   1.06381416e-13  1.71923688e-13  1.71923688e-13 -1.70336681e-13
#  -1.70336681e-13 -1.17774958e-13]
# <ggplot: (8751779375445)>

# %% [markdown]
# g. What is the standard deviation of this additive noise when you think it becomes hard to tell that the data is originally 2-dimensional (i.e. when there is a noticeable gap between the top to eigenvalues and the rest)? What is the corresponding variance of the additive noise?

# %%
# You can enter your answer as a comment here: 

###
### YOUR CODE HERE
###
print(S.std())
print(S_n.std())
# Out:
# 1.4343569437841777
# 5.062721541385043

# %% [markdown]
# ### Principal components analysis 1+2+2+2+2+2+2+2

# %% [markdown]
# Run the cell below to general 1000 2-dimensional Gaussians with mean 0 and covariance [[2,1.5], 1.5,2]]. These have also been stored in a dataframe for your convenience, you can use the latter for plotting.
#
# Like before the dataframe has 2 rows and 1000 columns, the dataframe is its transpose.

# %%
np.random.seed(1)

data2 = np.random.multivariate_normal([0,0], [[2,1.5],[1.5,2]], 1000)
data2_df = pd.DataFrame(data2, columns = ['x','y'])
data2 = data2.T

# %% [markdown]
# a. Create a scatterplot of the dataset

# %%
###
### YOUR CODE HERE
###

plt = ggplot() + geom_point(data2_df,aes(x='x',y='y'))

print(plt)
# Out:
# <ggplot: (-9223363285075396506)>

# %% [markdown]
# b. Compute the covariance matrix of the dataset, and store it in data_cv (this is a 2-by-2 matrix). Print it out.

# %%
###
### YOUR CODE HERE
###

data_cv = np.cov(data2)
print(data_cv)
# Out:
# [[1.98263953 1.52927341]
#  [1.52927341 2.08345601]]

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# c. Calculate the eigenvalues and eigenvectors of data_cv and store them in U and V. Print them out. Since this is a 2x2 matrix, you should not see any eigenvalues

# %%
###
### YOUR CODE HERE
###

U, V = np.linalg.eig(data_cv)
print(U)
print(V)
# Out:
# [0.50294381 3.56315174]
# [[-0.71865998 -0.69536166]
#  [ 0.69536166 -0.71865998]]

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# d. Recall that V is a rotation matrix. Rotate your original dataset by left-multiplying it by V. Call the result data_rot.

# %%
###
### YOUR CODE HERE
###

data_rot = np.dot(V,data2)

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# e. Create a scatterplot of the resulting dataset.
#
# (ggplot will rescale your data so that the x and y axes have different scales, which can be confusing. A simple way to fix this is to add
#
# " + xlim([-7,7]) + ylim([-7,7])  "
#
# to your ggplot object to fix a common range for both axes)

# %%
###
### YOUR CODE HERE
###

df = pd.DataFrame(data_rot.T, columns = ['x','y'])

plt = ggplot() + geom_point(df, aes(x='x',y='y')) + xlim([-7,7]) + ylim([-7,7])
print(plt)
# Out:
# <ggplot: (8751779297463)>

# %% [markdown]
# f. It should be clear after rotating our original dataset this way that the x-axis (or 1st row of data_rot is the direction of maximum variance, and that there is less variance along the y-axis (the second row in data_rot). We're going to do dimensionality reduction by setting the second row to 0. Create a scatterplot of the resulting matrix.

# %%
###
### YOUR CODE HERE
###

data_rot[1] = 0

df = pd.DataFrame(data_rot.T, columns = ['x','y'])

plt = ggplot() + geom_point(df, aes(x='x',y='y')) + xlim([-7,7]) + ylim([-7,7])
print(plt)
# Out:
# <ggplot: (8751779280360)>

# %% [markdown]
# g. Finally, we are going to rotate-back our matrix after dimensionality reduction. To do that, we multiply it by the inverse of V, or (since V is a rotation matrix) by the traspose of V. Do this, storing the result in a matrix data2_1d. Also plot a scatterplot of the rotated 1-d data.

# %%
###
### YOUR CODE HERE
###

data2_1d = np.dot(V.T,data_rot)
print(data2_1d)
# Out:
# [[-2.17849774  0.71900777 -1.14410576 ...  0.59996279 -0.74633028
#   -0.88188126]
#  [-2.10787278  0.69569818 -1.10701487 ...  0.58051253 -0.72213491
#   -0.85329145]]

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# h. Finally, to see clearly what is happening, create a single plot with two scatterplots. The first is the first 15 elements of data2, and the second is the first 15 elements of data2_1d. Color the latter in red.

# %%
###
### YOUR CODE HERE
###

data2_1d_df = pd.DataFrame(data2_1d.T, columns = ['x','y'])

plt = (ggplot() + geom_point(data2_df[0:15],aes(x='x',y='y')) + 
    geom_point(data2_1d_df[0:15],aes(x='x',y='y'),color='red'))
print(plt)
# Out:
# <ggplot: (-9223363285075530345)>
